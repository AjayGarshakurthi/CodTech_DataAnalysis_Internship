# %% [markdown]
# # Task 3: Dashboard Development
#
# This notebook points to the Dash dashboard implementation and provides the command needed to run it.

# %% [markdown]
# ## Dashboard script
#
# The interactive dashboard is implemented in [supermarket_dashboard.py](supermarket_dashboard.py).

# %%
print('Run the dashboard with: python supermarket_dashboard.py')
print('Then open: http://127.0.0.1:8050/')

# %% [markdown]
# ## Dashboard features
#
# - Filters for branch and product line
# - Summary metrics for total sales, average rating, and transaction count
# - Charts for branch sales, product sales, payment mix, and monthly trends
